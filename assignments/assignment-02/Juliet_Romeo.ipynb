# %%
#This code performs the necessary steps to prepare to plot.
from pylab import *     #Import plotting module matplotlib as well as other modules
                        #into the global namespace.

#Set the default plot to be inline rather than a new window.
# %matplotlib inline

# %%
a = 0.5
b = 1
c = 1
d = 1
R = 10
J = 10
steps = 10
t = 0.5
time = 0 
lst_R = []
lst_J = []
lst_time = []
for i in range(steps):
    lst_R.append(R)
    lst_J.append(J)
    lst_time.append(time)
    R = R + ((a * R) + (b * J ))* t
    J = J + ((c * R) + (d * J))* t
    time = time + t

    #Graph

goldenratio=1/2*(1+sqrt(5))        #The next few lines are used for the size of plots
fsx=7                              #Width (in inches) for the figures.
fsy=fsx/goldenratio                #Height (in inches) for the figures.
figure(figsize=(fsx, fsy))
plot(lst_time, lst_R, 'b-', label='Romeo Love')
plot(lst_time, lst_J, 'r-', label='Juliet Love')
legend(loc='upper center')
xlabel('Time')
ylabel('Love')
title('Love of Romeo and Juliet vs Time (Eager beaver = Romeo Love increases with Juliet)')
show()

# %%
a = 0.5
b = -1
c = 1
d = 1
R = 10
J = 10
steps = 10
t = 0.5
time = 0 
lst_R = []
lst_J = []
lst_time = []
for i in range(steps):
    lst_R.append(R)
    lst_J.append(J)
    lst_time.append(time)
    R = R + ((a * R) + (b * J ))* t
    J = J + ((c * R) + (d * J))* t
    time = time + t
    


goldenratio=1/2*(1+sqrt(5))        #The next few lines are used for the size of plots
fsx=7                              #Width (in inches) for the figures.
fsy=fsx/goldenratio                #Height (in inches) for the figures.
figure(figsize=(fsx, fsy))
plot(lst_time, lst_R, 'b-', label='Romeo Love')
plot(lst_time, lst_J, 'r-', label='Juliet Love')
legend(loc='upper center')
xlabel('Time')
ylabel('Love')
title('Love of Romeo and Juliet vs Time (Narcissistic nerd = Romeo wants more of what he feels)')
show()

# %%
a = -1
b = 1
c = 1
d = 1
R = 10
J = 10
steps = 10
t = 0.5
time = 0 
lst_R = []
lst_J = []
lst_time = []
for i in range(steps):
    lst_R.append(R)
    lst_J.append(J)
    lst_time.append(time)
    R = R + ((a * R) + (b * J ))* t
    J = J + ((c * R) + (d * J))* t
    time = time + t
    



goldenratio=1/2*(1+sqrt(5))        #The next few lines are used for the size of plots
fsx=7                              #Width (in inches) for the figures.
fsy=fsx/goldenratio                #Height (in inches) for the figures.
figure(figsize=(fsx, fsy))
plot(lst_time, lst_R, 'b-', label='Romeo Love')
plot(lst_time, lst_J, 'r-', label='Juliet Love')
legend(loc='upper center')
xlabel('Time')
ylabel('Love')
title('Love of Romeo and Juliet vs Time ( Cautious (or secure) lover = Romeo retreats from his own feelings)')
show()

# %%
a = -0.5
b = -1
c = 1
d = 1
R = 10
J = 10
steps = 10
t = 0.5
time = 0 
lst_R = []
lst_J = []
lst_time = []
for i in range(steps):
    lst_R.append(R)
    lst_J.append(J)
    lst_time.append(time)
    R = R + ((a * R) + (b * J ))* t
    J = J + ((c * R) + (d * J))* t
    time = time + t
    



goldenratio=1/2*(1+sqrt(5))        #The next few lines are used for the size of plots
fsx=7                              #Width (in inches) for the figures.
fsy=fsx/goldenratio                #Height (in inches) for the figures.
figure(figsize=(fsx, fsy))
plot(lst_time, lst_R, 'b-', label='Romeo Love')
plot(lst_time, lst_J, 'r-', label='Juliet Love')
legend(loc='upper center')
xlabel('Time')
ylabel('Love')
title('Love of Romeo and Juliet vs Time (Hermit = Romeo retreats from his own feelings as well as Juliet’s.)')
show()

# %%
a = 0.5
b = 1
c = 1
d = 1
R = 10
J = 10
steps = 10
t = 0.5
time = 0 
lst_R = []
lst_J = []
lst_time = []
for i in range(steps):
    lst_R.append(R)
    lst_J.append(J)
    lst_time.append(time)
    R = R + ((a * R) + (b * J ))* t
    J = J + ((c * R) + (d * J))* t
    time = time + t
    
#Graph

goldenratio=1/2*(1+sqrt(5))        #The next few lines are used for the size of plots
fsx=7                              #Width (in inches) for the figures.
fsy=fsx/goldenratio                #Height (in inches) for the figures.
figure(figsize=(fsx, fsy))
plot(lst_R, lst_J, 'b-')
# plot(lst_time, lst_J, 'r-', label='Juliet Love')
legend(loc='upper center')
xlabel('Romeo Love')
ylabel('Juliet Love')
title('Love of Romeo vs Juliet  (Eager beaver = Romeo Love increases with Juliet)')
show()
# Out:
# No handles with labels found to put in legend.

# %%
a = 0.5
b = -1
c = 1
d = 1
R = 10
J = 10
steps = 10
t = 0.5
time = 0 
lst_R = []
lst_J = []
lst_time = []
for i in range(steps):
    lst_R.append(R)
    lst_J.append(J)
    lst_time.append(time)
    R = R + ((a * R) + (b * J ))* t
    J = J + ((c * R) + (d * J))* t
    time = time + t
    


goldenratio=1/2*(1+sqrt(5))        #The next few lines are used for the size of plots
fsx=7                              #Width (in inches) for the figures.
fsy=fsx/goldenratio                #Height (in inches) for the figures.
figure(figsize=(fsx, fsy))
plot(lst_R, lst_J, 'b-')
# plot(lst_time, lst_J, 'r-', label='Juliet Love')
legend(loc='upper center')
xlabel('Romeo Love')
ylabel('Juliet Love')
title('Love of Romeo vs Juliet  (Narcissistic nerd = Romeo wants more of what he feels)')
show()
# Out:
# No handles with labels found to put in legend.

# %%
a = -1
b = 1
c = 1
d = 1
R = 10
J = 10
steps = 10
t = 0.5
time = 0 
lst_R = []
lst_J = []
lst_time = []
for i in range(steps):
    lst_R.append(R)
    lst_J.append(J)
    lst_time.append(time)
    R = R + ((a * R) + (b * J ))* t
    J = J + ((c * R) + (d * J))* t
    time = time + t
    



goldenratio=1/2*(1+sqrt(5))        #The next few lines are used for the size of plots
fsx=7                              #Width (in inches) for the figures.
fsy=fsx/goldenratio                #Height (in inches) for the figures.
figure(figsize=(fsx, fsy))

plot(lst_R, lst_J, 'b-')
# plot(lst_time, lst_J, 'r-', label='Juliet Love')
legend(loc='upper center')
xlabel('Romeo Love')
ylabel('Juliet Love')
title('Love of Romeo vs Juliet ( Cautious (or secure) lover = Romeo retreats from his own feelings)')
show()
# Out:
# No handles with labels found to put in legend.

# %%
a = -0.5
b = -1
c = 1
d = 1
R = 10
J = 10
steps = 10
t = 0.5
time = 0 
lst_R = []
lst_J = []
lst_time = []
for i in range(steps):
    lst_R.append(R)
    lst_J.append(J)
    lst_time.append(time)
    R = R + ((a * R) + (b * J ))* t
    J = J + ((c * R) + (d * J))* t
    time = time + t
    



goldenratio=1/2*(1+sqrt(5))        #The next few lines are used for the size of plots
fsx=7                              #Width (in inches) for the figures.
fsy=fsx/goldenratio                #Height (in inches) for the figures.
figure(figsize=(fsx, fsy))
plot(lst_R, lst_J, 'b-')
# plot(lst_time, lst_J, 'r-', label='Juliet Love')
legend(loc='upper center')
xlabel('Romeo Love')
ylabel('Juliet Love')
title('Love of Romeo vs Juliet (Hermit = Romeo retreats from his own feelings as well as Juliet’s.)')
show()
# Out:
# No handles with labels found to put in legend.
